# %%
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
import folium
from folium import Marker

# %%
geolocator = Nominatim(user_agent="kaggle_learn")
location = geolocator.geocode("HD1 3AY")

print(location.point)
print(location.address)
# Out:
# 53 38m 21.444s N, 1 46m 49.44s W
# HD1 3AY, Kirklees, West Yorkshire, England, United Kingdom

# %%
point = location.point

print(location.latitude)
print(location.longitude)
# Out:
# 53.63929
# -1.7804

# %%
universities = pd.read_csv('top_universities.csv')

universities.head()
# Out:
#                       Name
# 0     University of Oxford
# 1  University of Cambridge
# 2  Imperial College London
# 3               ETH Zurich
# 4                      UCL

# %%
def my_geocoder(row):
    try:
        point = geolocator.geocode(row).point
        return pd.Series({'Latitude': point.latitude, 'Longitude': point.longitude})
    except:
        return None

universities[['Latitude', 'Longitude']] = universities.apply(lambda x: my_geocoder(x['Name']), axis=1)


print("{}% of addresses were geocoded!".format(
    (1 - sum(np.isnan(universities["Latitude"])) / len(universities)) * 100))
# Out:
# 90.0% of addresses were geocoded!

# %%
# Drop universities that were not successfully geocoded
import geopandas as gpd
universities = universities.loc[~np.isnan(universities["Latitude"])]
universities = gpd.GeoDataFrame(
    universities, geometry=gpd.points_from_xy(universities.Longitude, universities.Latitude), crs='epsg:4326')
# universities.crs = {'init': 'epsg:4326'}
universities.head()
# Out:
#                       Name   Latitude  Longitude                   geometry
# 0     University of Oxford  51.758708  -1.255668  POINT (-1.25567 51.75871)
# 1  University of Cambridge  52.210946   0.092005     POINT (0.092 52.21095)
# 2  Imperial College London  51.498959  -0.175641  POINT (-0.17564 51.49896)
# 3               ETH Zurich  47.413218   8.537491   POINT (8.53749 47.41322)
# 4                      UCL  51.521785  -0.135151  POINT (-0.13515 51.52179)

# %%
m = folium.Map(location=[54, 15], tiles='openstreetmap', zoom_start=2)

for idx, row in universities.iterrows():
     Marker([row['Latitude'], row['Longitude']], popup=row['Name']).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39cc687f19125c4bbda3ac48551c1940 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39cc687f19125c4bbda3ac48551c1940&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39cc687f19125c4bbda3ac48551c1940 = L.map(
#                 &quot;map_39cc687f19125c4bbda3ac48551c1940&quot;,
#                 {
#                     center: [54.0, 15.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d4df0b33516e587a71418bc1f174455 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5d4df0b33516e587a71418bc1f174455.addTo(map_39cc687f19125c4bbda3ac48551c1940);
#
#
#             var marker_901b22272d8e92d9e8c497e5a5a6046a = L.marker(
#                 [51.75870755, -1.2556684826092037],
#                 {}
#             ).addTo(map_39cc687f19125c4bbda3ac48551c1940);
#
#
#         var popup_50f676618ee59966722fd0038a1ee257 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bd9b366b8ad7c3fca9711209531f740 = $(`&lt;div id=&quot;html_6bd9b366b8ad7c3fca9711209531f740&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Oxford&lt;/div&gt;`)[0];
#                 popup_50f676618ee59966722fd0038a1ee257.setContent(html_6bd9b366b8ad7c3fca9711209531f740);
#
#
#
#         marker_901b22272d8e92d9e8c497e5a5a6046a.bindPopup(popup_50f676618ee59966722fd0038a1ee257)
#         ;
#
#
#
#
#             var marker_6bad0659aaa2085756db6abad2d8ddb2 = L.marker(
#                 [52.210945550000005, 0.09200497637871279],
#                 {}
#             ).addTo(map_39cc687f19125c4bbda3ac48551c1940);
#
#
#         var popup_1d77a1386c9e33806f3be4390a5ea505 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ccd1cc870650ea6d5dadaa852686974 = $(`&lt;div id=&quot;html_4ccd1cc870650ea6d5dadaa852686974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;University of Cambridge&lt;/div&gt;`)[0];
#                 popup_1d77a1386c9e33806f3be4390a5ea505.setContent(html_4ccd1cc870650ea6d5dadaa852686974);
#
#
#
#         marker_6bad0659aaa2085756db6abad2d8ddb2.bindPopup(popup_1d77a1386c9e33806f3be4390a5ea505)
#         ;
#
#
#
#
#             var marker_801f42de6515ff325baec222f3b447a8 = L.marker(
#                 [51.4989595, -0.17564069276310426],
#                 {}
#             ).addTo(map_39cc687f19125c4bbda3ac48551c1940);
#
#
#         var popup_6ee23fe7a63aa6693520baa5b3cf9c18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5945d2fb56096efa48c791355923acf7 = $(`&lt;div id=&quot;html_5945d2fb56096efa48c791355923acf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Imperial College London&lt;/div&gt;`)[0];
#                 popup_6ee23fe7a63aa6693520baa5b3cf9c18.setContent(html_5945d2fb56096efa48c791355923acf7);
#
#
#
#         marker_801f42de6515ff325baec222f3b447a8.bindPopup(popup_6ee23fe7a63aa6693520baa5b3cf9c18)
#         ;
#
#
#
#
#             var marker_599e608415fca4bf4915a77fbd28a0f2 = L.marker(
#                 [47.413218, 8.5374914],
#                 {}
#             ).addTo(map_39cc687f19125c4bbda3ac48551c1940);
#
#
#         var popup_c21ab14e75a254bdd63415970cc86784 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d12b7226712d7f4d15017fc8b497ca3 = $(`&lt;div id=&quot;html_5d12b7226712d7f4d15017fc8b497ca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ETH Zurich&lt;/div&gt;`)[0];
#                 popup_c21ab14e75a254bdd63415970cc86784.setContent(html_5d12b7226712d7f4d15017fc8b497ca3);
#
#
#
#         marker_599e608415fca4bf4915a77fbd28a0f2.bindPopup(popup_c21ab14e75a254bdd63415970cc86784)
#         ;
#
#
#
#
#             var marker_1b1d4452129f3ce81a0ddeb4b80e18d7 = L.marker(
#                 [51.5217852, -0.13515149671251314],
#                 {}
#             ).addTo(map_39cc687f19125c4bbda3ac48551c1940);
#
#
#         var popup_d438fc7d6c4e71b32b62141f37cde3ca = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_30f2d4bfef917b8baae40f7fd6d62be3 = $(`&lt;div id=&quot;html_30f2d4bfef917b8baae40f7fd6d62be3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UCL&lt;/div&gt;`)[0];
#                 popup_d438fc7d6c4e71b32b62141f37cde3ca.setContent(html_30f2d4bfef917b8baae40f7fd6d62be3);
#
#
#
#         marker_1b1d4452129f3ce81a0ddeb4b80e18d7.bindPopup(popup_d438fc7d6c4e71b32b62141f37cde3ca)
#         ;
#
#
#
#
#             var marker_87019afcdccd89f5a4366c9b2fb5f9c9 = L.marker(
#                 [51.51426105, -0.11673351981492822],

# %%
from common_utils import EUROPEAN_COUNTRIES
world = gpd.read_file('../natural-earth-countries-1_110m.geojson')
europe = world[world.sovereignt.isin(EUROPEAN_COUNTRIES)].reset_index(drop=True)

europe_stats = europe[['featurecla', 'scalerank', 'sovereignt']]
europe_boundries = europe[['sovereignt', 'geometry']]


europe_stats.head()
# Out:
#         featurecla  scalerank   sovereignt
# 0  Admin-0 country          1      Croatia
# 1  Admin-0 country          1       France
# 2  Admin-0 country          1      Ukraine
# 3  Admin-0 country          1  Switzerland
# 4  Admin-0 country          1   Luxembourg

# %%
europe = europe_boundries.merge(europe_stats, on='sovereignt')
europe.head()
# Out:
#   sovereignt                                           geometry  \
# 0    Croatia  POLYGON ((16.56481 46.50375, 16.88252 46.38063...
# 1     France  POLYGON ((165.77999 -21.08, 166.59999 -21.7000...
# 2     France  POLYGON ((165.77999 -21.08, 166.59999 -21.7000...
# 3     France  POLYGON ((165.77999 -21.08, 166.59999 -21.7000...
# 4    Ukraine  POLYGON ((31.78599 52.10168, 32.15944 52.06125...
#
#         featurecla  scalerank
# 0  Admin-0 country          1
# 1  Admin-0 country          1
# 2  Admin-0 country          3
# 3  Admin-0 country          1
# 4  Admin-0 country          1

# %%
european_universities = gpd.sjoin(universities, europe)


print("We located {} universities.".format(len(universities)))
print("Only {} of the universities were located in Europe (in {} different countries).".format(
    len(european_universities), len(european_universities.sovereignt.unique())))

european_universities.head()
# Out:
# We located 90 universities.
# Only 124 of the universities were located in Europe (in 15 different countries).
#                       Name   Latitude  Longitude                   geometry  \
# 0     University of Oxford  51.758708  -1.255668  POINT (-1.25567 51.75871)
# 0     University of Oxford  51.758708  -1.255668  POINT (-1.25567 51.75871)
# 1  University of Cambridge  52.210946   0.092005     POINT (0.092 52.21095)
# 1  University of Cambridge  52.210946   0.092005     POINT (0.092 52.21095)
# 2  Imperial College London  51.498959  -0.175641  POINT (-0.17564 51.49896)
#
#    index_right      sovereignt       featurecla  scalerank
# 0           11  United Kingdom  Admin-0 country          1
# 0           12  United Kingdom  Admin-0 country          1
# 1           11  United Kingdom  Admin-0 country          1
# 1           12  United Kingdom  Admin-0 country          1
# 2           11  United Kingdom  Admin-0 country          1

# %%
# Out:
# 'common_utils'
