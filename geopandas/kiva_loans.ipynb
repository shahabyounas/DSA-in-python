# %%
import geopandas as gpd
import geodatasets
from geodatasets import get_path

gdf = gpd.read_file('./data/kiva/kiva_loans.shp')

world_filepath = get_path("naturalearth.land")

# %%
world_filepath
world = gpd.read_file(world_filepath)
gdf
# Out:
#        Partner ID                       Field Part  \
# 0               9  KREDIT Microfinance Institution
# 1               9  KREDIT Microfinance Institution
# 2               9  KREDIT Microfinance Institution
# 3               9  KREDIT Microfinance Institution
# 4               9  KREDIT Microfinance Institution
# ...           ...                              ...
# 13657         539           N/A, direct to Sevamob
# 13658         540           N/A, direct to Sanergy
# 13659         542       N/A direct to BioLite Inc.
# 13660         543      N/A direct to LegWorks Inc.
# 13661         545        N/A, direct to Solar Home
#
#                             sector              Loan Theme          country  \
# 0      General Financial Inclusion        Higher Education         Cambodia
# 1      General Financial Inclusion  Vulnerable Populations         Cambodia
# 2      General Financial Inclusion        Higher Education         Cambodia
# ...
